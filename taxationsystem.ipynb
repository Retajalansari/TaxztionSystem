# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Thu Nov 28 01:30:14 2019

@author: ratajalansari
"""

def main():
    print('||******************************||')
    print('    ''Welcome to Taxation System')
    print('||******************************||')
    displayMenu()
    choice = input(('Enter your choice(A or B or C): '))
    choices = ['A','a','B','b','C','c']
    while choice not in choices:
        print('------------------------------')
        print('Worng entry!\nYou should enter A for America or B for Australia or C to Exit!\nTry Again!')
        print('------------------------------')
        displayMenu()
        choice = input(('Enter your choice(A or B or C): '))
    if choice == 'A' and 'a':
        ITIN = input('Enter the Individual Taxpayer Identification Number (ITIN): ')
    boolenus = isValid_ITIN(ITIN)
    while boolenus == False:
        print('Wrong entry, ITIN does not follow the rules!\nTry again!')
        ITIN = list(input('Enter the Individual Taxpayer Identification Number (ITIN): '))
    name = input('Enter your Full name: ')
    salary = float(input('Enter your annual Salary: '))
    while salary < 0:
        print('---------------------------')
        print('Incorrect salary value: \nTry Again')
        print('---------------------------')
        salary = float(input('Enter your annual Salary: '))
    print('---------------------------')
    print('The Entered data:\nFull name: ',name,'\nITIN: ',ITIN,
          '\nThe annual Salary:',salary,'$')
    print('---------------------------')
   
    
    
    Taxus = US_TaxPaid(salary)
    print("The Citizen's !" + " Tax-payable ammount is:",
          format(Taxus, ',.2f'),'$',sep='')
    print("The citizen's record has been written to the output file.")
    
    if choice == 'B' or 'b':
        TFN = list(input('Enter the Tax File Number (TFN): '))
        isValid_TFN(TFN)
        name = input('Enter your Full name: ')
        salary = float(input('Enter your annual Salary: '))
        if salary >= 0:
            print('---------------------------')
            print('The Entered data:\nFull name: ',name,'\nTFN: ',TFN,
                  '\nThe annual Salary:',salary,'$')
            print('---------------------------')
            Taxau = AU_TaxPaid(salary)
            print("The citizen's !" + " Tax-payable ammount is:",
                  format(Taxau, ',.2f'),'$',sep='')
            print("The citizen's record has been written to the output file.")
        else:
            while salary < 0:
                print('---------------------------')
                print('Incorrect salary value: \nTry Again')
                print('---------------------------')
                salary = float(input('Enter your annual Salary: '))
        



def displayMenu():
    print('||*************** Menu ***************||')
    print('Please select the country:\nA. Amereica\nB. Australia\nC. Exit')
    print('||******************************||')

def isValid_ITIN(ITIN):
    if len(ITIN) == 9:
        stat = True
        if ITIN[0] == 9:
            stat = True
            if ITIN[3:5] in range(70,89):
                stat = True
                if ITIN[3:5] != 93 and ITIN[3:5] != 100:
                    stat = True
                else:
                    stat = False
    return stat
                

def isValid_TFN(TFN):
    while len(TFN) != 9:
        print('Wrong entry, TFN should be 9 digits!\nTry again!')
        TFN = list(input('Enter the Tax File Number (TFN): '))   
        if len(TFN) == 9:
            stat = True
        else:
            stat = False
    return stat
        
def US_TaxPaid(salary):
    if 0 <= salary <= 8700:
        AmereicaTaxPaid1 = salary*0.10
        print('---------------------------')
        print('Thanks for Using Taxation Sestem')
    else: 
        if 8701 <= salary <= 35350:
            AmereicaTaxPaid2 = salary*0.15
            print('---------------------------')
            print('Thanks for Using Taxation Sestem')
        else:
            if 35351 <= salary <= 85650:
                AmereicaTaxPaid3 = salary*0.25
                print('---------------------------')
                print('Thanks for Using Taxation Sestem')
            else:
                if 85651 <= salary <= 178650:
                    AmereicaTaxPaid4 = salary*0.28
                    print('---------------------------')
                    print('Thanks for Using Taxation Sestem')
                else:  
                    if 178651 <= salary <= 388350:
                        AmereicaTaxPaid5 = salary*0.33
                        print('---------------------------')
                        print('Thanks for Using Taxation Sestem')
                    else:   
                        if salary >= 388351:
                            AmereicaTaxPaid6 = salary*0.35
    return AmereicaTaxPaid1,AmereicaTaxPaid2,AmereicaTaxPaid3,AmereicaTaxPaid4,AmereicaTaxPaid5,AmereicaTaxPaid6

def AU_TaxPaid(salary):
    if 0 <= salary <= 6000:
        AustraliaTaxPaid1 = 'none'
        print('---------------------------')
        print('Thanks for Using Taxation Sestem')
    else: 
        if 6001 <= salary <= 37000:
            AustraliaTaxPaid2 = salary*0.15
            print('---------------------------')
            print('Thanks for Using Taxation Sestem')
        else:    
            if 37000 <= salary <= 80000:
                AustraliaTaxPaid3 = salary*0.30
                print('---------------------------')
                print('Thanks for Using Taxation Sestem')
            else:
                if 80001 <= salary <= 180000:
                    AustraliaTaxPaid4 = salary*0.37
                    print('---------------------------')
                    print('Thanks for Using Taxation Sestem')
                else:
                    if salary >= 180001:
                        AustraliaTaxPaid5 = salary*0.45
                        print('---------------------------')
                        print('Thanks for Using Taxation Sestem')
    return AustraliaTaxPaid1,AustraliaTaxPaid2,AustraliaTaxPaid3,AustraliaTaxPaid4,AustraliaTaxPaid5
main()
